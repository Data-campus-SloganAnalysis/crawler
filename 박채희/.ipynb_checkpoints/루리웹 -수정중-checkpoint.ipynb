# %%
import re
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd


options = webdriver.ChromeOptions()
options.add_argument("headless")

# %%
driver_path = 'C:/Users/chaeh/chromedriver.exe'

# %%
def clean_text(text):
    cleaned_text = re.sub('[a-zA-Z]', '', text)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]',
                          '', cleaned_text)
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# %%
def ruli(query, driver_path, page):
    driver = webdriver.Chrome(executable_path=driver_path)
    text= []
    
    for i in range(1, page+1):
        base_url = 'https://bbs.ruliweb.com/search?q='
        url = base_url + query + '&c_page='+str(i) +'#comment_search&gsc.tab=0&gsc.q='+query+'&gsc.page=1'
        driver.get(url)
        driver.refresh()
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        for j in range(1,16):
            title=soup.select('#comment_search > div > ul > li:nth-of-type('+str(j)+') > div > div > a.title.text_over')
            title=title[0].text
            title=clean_text(title)
            text.append(title)
    driver.close()
    return text

# %%
ruli('삼성전자', driver_path, 10)
# Out:
# ['개발자 대상인데 삼성전자에서 개발하나', '작년초에는 시총비중 30 넘어가서 무슨무슨 규정때문에 인덱스 펀드들 강제로 삼성전자 비중 줄여야 된다는 이야기있었는데 삼', '역시 삼성전자 정직원 답네 ㅋㅋㅋㅋㅋㅋㅋ 언젠가부터 리뷰가 아니라 광고영상 같더니만', '비트코인 테슬라 삼성전자 오케이', '난 집근처에 스타필드시티있는데 거기안에 삼성전자매장인가 있어서 가보니까 잇더라', '삼성전자 74층에 사람있어요', '미국 넘어가자마자 삼성전자 부서별로 하나씩 회사 뜯겨나가지고 계열사들 싸그리 정리당할건 알고 저 소리하려나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '국익이라 삼바 덕분에 우리나라 이제 코로나 종식되나 아님 뭐 삼성전자 덕분에 경제 활성화 되나 아님 뭐 삼성전자가 이번에', '현대말고 삼성전자를 사셨다면', '절 못믿으시더라도 삼성은 믿으셔야죠 저거 틀렸다고 삼성전자에 따져서 확답받으시길 바랍니다', '기사 본문은 보셨어요 기존 플래그십 라인업인 갤럭시노트를 포기하고 주력한 폴더블인 만큼 흥행', '8만까지 오른 것도 엄청나게 오를걸로 아는데 지금까지 안 판 사람들은 왜 가지고 있는거야 주식 하나도 모르는 나도 요 1년', '삼성전자가 문제가 아니다 하닉 20 찍음 ㅅㅂ ㅠㅜ 카카오 네이버로 번거 삼전 하이닉스로 다날리네', '삼성전자에서 배워왔겠지 ㅋㅋ', '전 삼성전자 전무 있네 걔가 배워 왓겠지']
# ...
