# %%
import pandas as pd

test = pd.read_csv('풀무원 바른먹거리.csv',encoding='UTF-8',index_col = 0)

# %%
test
# Out:
#       언론사                                       제목  \
# 0    경향신문              ‘바른 먹거리’ 풀무원 물류센터에서는 무슨 일이?
# 1    경향신문  어린이 ‘바른 먹거리 캠페인’ 신청하세요… 풀무원, 사회공헌 교육 확대
# 2    경향신문                  풀무원, 어린이 바른 먹거리 현장 체험교육
# 3    경향신문              풀무원 ‘바른 먹을거리 교육’에 어린이 신청 늘어
# 4    경향신문     풀무원, 13년 만에 새 CI 발표... 글로벌 로하스 도약 목표
# ..    ...                                      ...
# 249   한겨례              “일 25씩 더 해 기부하면 세계 굶주림 사라져”
# 250  한국일보                 냉면·짜장·떡볶이 제품에 트레이가 필요한가요
# 251  한국일보      풀무원 입사 1호 사원이 … 성장세 발목 잡던 해외 실적도 개선
# 252  한국일보         풀무원 13년 만에 기업이미지 바꿔… 계열사 브랜드도 통일
# 253  한국일보                    위원회 출범하고 도…식품업계 경영 속도
#
#                                                     내용
# 0    지난 16일 사회관계망서비스에서는 차밑에 들어가 있는 한 노동자의 사진이 화제를 모...
# 1    풀무원이 어린이들의 바른 식생활을 위해 2010년부터 실시해온 ‘바른 먹거리 캠페인...
# 2    풀무원 홀딩스는 초등학교 여름방학을 맞아 충북 음성 풀무원 두부공장을 돌아보는 ‘풀...
# 3    어린이를 대상으로 한 올바른 먹을거리 교육이 학교와 학부모들로부터 관심을 모으고 있...
# 4    풀무원 새 풀무원이 2005년 이후 13년 만에 기업이미지를 교체했다. 계열사 브랜...
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 0 to 253
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   언론사     254 non-null    object
#  1   제목      254 non-null    object
#  2   내용      251 non-null    object
# dtypes: object(3)
# memory usage: 7.9+ KB

# %%
test=test.dropna()

# %%
test
# Out:
#       언론사                                       제목  \
# 0    경향신문              ‘바른 먹거리’ 풀무원 물류센터에서는 무슨 일이?
# 1    경향신문  어린이 ‘바른 먹거리 캠페인’ 신청하세요… 풀무원, 사회공헌 교육 확대
# 2    경향신문                  풀무원, 어린이 바른 먹거리 현장 체험교육
# 3    경향신문              풀무원 ‘바른 먹을거리 교육’에 어린이 신청 늘어
# 4    경향신문     풀무원, 13년 만에 새 CI 발표... 글로벌 로하스 도약 목표
# ..    ...                                      ...
# 249   한겨례              “일 25씩 더 해 기부하면 세계 굶주림 사라져”
# 250  한국일보                 냉면·짜장·떡볶이 제품에 트레이가 필요한가요
# 251  한국일보      풀무원 입사 1호 사원이 … 성장세 발목 잡던 해외 실적도 개선
# 252  한국일보         풀무원 13년 만에 기업이미지 바꿔… 계열사 브랜드도 통일
# 253  한국일보                    위원회 출범하고 도…식품업계 경영 속도
#
#                                                     내용
# 0    지난 16일 사회관계망서비스에서는 차밑에 들어가 있는 한 노동자의 사진이 화제를 모...
# 1    풀무원이 어린이들의 바른 식생활을 위해 2010년부터 실시해온 ‘바른 먹거리 캠페인...
# 2    풀무원 홀딩스는 초등학교 여름방학을 맞아 충북 음성 풀무원 두부공장을 돌아보는 ‘풀...
# 3    어린이를 대상으로 한 올바른 먹을거리 교육이 학교와 학부모들로부터 관심을 모으고 있...
# 4    풀무원 새 풀무원이 2005년 이후 13년 만에 기업이미지를 교체했다. 계열사 브랜...
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251 entries, 0 to 253
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   언론사     251 non-null    object
#  1   제목      251 non-null    object
#  2   내용      251 non-null    object
# dtypes: object(3)
# memory usage: 7.8+ KB

# %%
test['문장']=''
for x in range(0,254):
    try:
        text=test['내용'][x]
        text=text.split('.')
    except:
        print('')
   
    #print(text)
    test['문장'][x]=text
# Out:
# C:\Users\chaeh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chaeh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\chaeh\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
test
# Out:
#       언론사                                       제목  \
# 0    경향신문              ‘바른 먹거리’ 풀무원 물류센터에서는 무슨 일이?
# 1    경향신문  어린이 ‘바른 먹거리 캠페인’ 신청하세요… 풀무원, 사회공헌 교육 확대
# 2    경향신문                  풀무원, 어린이 바른 먹거리 현장 체험교육
# 3    경향신문              풀무원 ‘바른 먹을거리 교육’에 어린이 신청 늘어
# 4    경향신문     풀무원, 13년 만에 새 CI 발표... 글로벌 로하스 도약 목표
# ..    ...                                      ...
# 249   한겨례              “일 25씩 더 해 기부하면 세계 굶주림 사라져”
# 250  한국일보                 냉면·짜장·떡볶이 제품에 트레이가 필요한가요
# 251  한국일보      풀무원 입사 1호 사원이 … 성장세 발목 잡던 해외 실적도 개선
# 252  한국일보         풀무원 13년 만에 기업이미지 바꿔… 계열사 브랜드도 통일
# 253  한국일보                    위원회 출범하고 도…식품업계 경영 속도
#
#                                                     내용  \
# 0    지난 16일 사회관계망서비스에서는 차밑에 들어가 있는 한 노동자의 사진이 화제를 모...
# 1    풀무원이 어린이들의 바른 식생활을 위해 2010년부터 실시해온 ‘바른 먹거리 캠페인...
# 2    풀무원 홀딩스는 초등학교 여름방학을 맞아 충북 음성 풀무원 두부공장을 돌아보는 ‘풀...
# 3    어린이를 대상으로 한 올바른 먹을거리 교육이 학교와 학부모들로부터 관심을 모으고 있...
# 4    풀무원 새 풀무원이 2005년 이후 13년 만에 기업이미지를 교체했다. 계열사 브랜...
# ...

# %%
test.to_csv('풀무원 바른먹거리 문장ver.csv',encoding='UTF-8')
