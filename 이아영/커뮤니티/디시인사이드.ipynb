# %%
import re
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd

# %%
driver_path = 'C:/chromedriver_win32/chromedriver.exe'

# %%
def dc(query, driver_path, page):
    
    driver = webdriver.Chrome(executable_path=driver_path)
    
    text= []
    
    for i in range(1, page+1):
        post_links = []
        
        base_url = 'https://search.dcinside.com/post/q/.'
        
        url = base_url + query + '/p/'+str(i)
       
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        for j in range(1,26):
            post_links.append(soup.select('#container > div > section.center_content > div.inner > div.integrate_cont.sch_result.result_all > ul > li:nth-of-type('+str(j)+') > a'))
            
            
        for k in range(len(post_links)):
            
            try:
                link_url =  post_links[k][0].get('href')
                driver.get(link_url)
                soup = BeautifulSoup(driver.page_source , 'html.parser')
                temp = soup.find_all('div',class_='write_div')[0].text
                
                text.append(temp)
            except:
                
                print('error_link: ', post_links[k])
    driver.close()
    return text

# %%
text = dc('삼성전자', driver_path, 5)
# Out:
# error_link:  []
# error_link:  []
# error_link:  []

# %%
def clean_text(text):
    cleaned_text = re.sub('[a-zA-Z]', '', text)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]',
                          '', cleaned_text)
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# %%
text = " ". join(text)
clean_text(text)
# Out:
# '오늘 공개래효정 갤럭시 이어서 잘나가네 816월 1000 · 삼성전자 유튜브 리얼 마케팅쇼승희 \u200b 이번주 일정 2220185 좋아해 널 꽤 아주 많이 삼성전자 레노버 세개 중에 살려하는데 상품의견은 삼성이 많던데 역시 삼성이 좋은가요 재용이형님 출소 및손흥민 장기 재계약 기념 삼성전자전통의 경부노선신도시강남접근성롯데백화점마그나 공항접근성7호선스타필드 아산병원누가 6시부터 시작 방번호 45분에 공개 1등 삼성 전자레인지 지 않냐 왕개미 연구소 25 “어나더 월드네요”국내 주식 종목들이 온통 파란색으로 물들었던 지난 13일의 금요일 이후 투자자들 사이에선 코인계의 전설이라는 ‘워뇨띠’의 삼성전자 입주 인증샷이 화제였다워뇨띠는 가상화폐 투자자들이라면 모르는 사람이 없을 정도로 유명한 ‘코인 레전드’다 온라인 유명 게시판에 본인의 코인 계좌 수익률을 공개하면서 주목을 받기 시작했다 하지만 종잣돈 600만원으로 코인 투자를 시작해서 2500억원을 모은 20대 투자자라는 정도만 알려져 있을 뿐 어디에 살고 어떤 일을 하는지는 베일에 가려져 있다일부 투자자들은 워뇨띠의 계좌 인증샷이 조작된 것이라서 실존 인물인지 믿을 수 없다고 지적하기도 한다 하지만 일본의 가상화폐 거래소인 비트맥스를 보면 워뇨띠가 실제로 코인투자 수익률 상위권에 랭크되어 있다 코인러들은 워뇨띠를 코인계의 신神으로 모시면서 ‘갓뇨띠’라고 칭송하고 그의 매매 기술을 배우려고 따라 다닌다비트맥스는 다른 가상화폐 거래소와 달리 투자자들의 수익률 순위를 공개하는 화면리더보드을 마련해 놨다 라는 이름으로 활약 중인 워뇨띠는 4위이고 16일 오전 기준 전체 수익률은 3172비트약 1750억원에 달한다 비트맥스 캡처 그런데 코인계의 거물이라는 워뇨띠가 지난 주 삼성전자 주식을 520억원 어치 사서 보유 중이라는 계좌 인증샷이 등장했다 그의 평균 매입 단가는 8만1500원으로 13일 삼성전자 주가 급락분을 반영한 평가 손실은 45억원에 달한다 서울 반포의 한강뷰 아