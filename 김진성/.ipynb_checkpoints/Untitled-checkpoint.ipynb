# %%
import pandas as pd
import os

csv_list = os.listdir('../csv모음')

# %%
for i in csv_list:
    try:
        print(pd.read_csv('../csv모음/'+i,encoding='utf-8'))
    except:
        print(pd.read_csv('../csv모음/'+i,encoding='cp949'))
# Out:
#      언론사                                                 제목  \
# 0   경향신문                        ‘바른 먹거리’ 풀무원 물류센터에서는 무슨 일이?
# 1   경향신문                            풀무원, 어린이 바른 먹거리 현장 체험교육
# 2   경향신문  풀무원다논의 ‘다논 그릭’, 고단백 저지방 깊고 진한 풍미로 그릭요거트 시장 판매 ...
# 3   경향신문                      풀무원, ‘식물성유산균 치아씨드 오메가’ 리뉴얼 출시
# 4   경향신문                            풀무원베이비밀 ‘백일되면 베이비밀’ 이벤트
# 5   경향신문                                        풀무원 페이스북 오픈
# 6   경향신문                       풀무원 ‘굿바이 아토피!’ …어린이 예방·치료 앞장
# 7   경향신문            어린이 ‘바른 먹거리 캠페인’ 신청하세요… 풀무원, 사회공헌 교육 확대
# 8   경향신문                            ‘두부 한모’로 솜씨 겨루는 요리대회 열려
# 9   경향신문               풀무원, 13년 만에 새 CI 발표... 글로벌 로하스 도약 목표
# 10  경향신문                        풀무원 ‘바른 먹을거리 교육’에 어린이 신청 늘어
# 11  경향신문                           풀무원, 중국 가공계란 사업에 뛰어든 까닭은
# 12  경향신문                   박남주 풀무원식품 부사장 등 63명 대한민국 신지식인 선정
# 13  경향신문                                 풀무원, 홈페이지에 식품정보 공개
# 14  경향신문                     [나눔경영]풀무원-‘굿바이 아토피’ 어린이 치료에 앞장
# ...

# %%
temp = pd.read_csv('../csv모음/아시아투데이.csv',encoding='utf-8')

# %%
temp
# Out:
#     Unnamed: 0     언론사                                                 제목  \
# 0            0  아시아투데이                 풀무원, ‘바른먹거리 캠페인’ 전국 확대…2만여명에 무상 교육
# 1            1  아시아투데이                  풀무원다논, 무주 공장 요거트 생산라인 증설…239억원 투입
# 2            2  아시아투데이              풀무원식품, 신임 대표에 김진홍 전 LG전자 글로벌마케팅센터장 선임
# 3            3  아시아투데이                풀무원, 어린이 2만2000명에 ‘바른먹거리 캠페인 교육’ 실시
# 4            4  아시아투데이                 풀무원, ‘대한민국소셜미디어대상’ 종합식품·소셜브랜드부문 대상
# 5            5  아시아투데이  풀무원, 어른들을 위한 ‘성인 바른먹거리 교육’ 실시…“어른이 먼저 불균형 식습관 ...
# 6            6  아시아투데이                              풀무원 ‘바른먹거리 교육’ 영역 넓힌다
# 7            7  아시아투데이                  풀무원녹즙, 3중 필터링 거친 노니주스 ‘노니엔클리어’ 출시
# 8            8  아시아투데이                       풀무원, ‘바른먹거리’ 교육 확대…올해 1만명 실시
# 9            9  아시아투데이       “용기째 요리”…풀무원, 용기형 가정간편식 ‘5분 키친 순두부 요리’ 3종 출시
# 10          10  아시아투데이                      풀무원, 간편식 ‘5분 키친 콩나물 요리’ 3종 선봬
# 11          11  아시아투데이                   풀무원, 11년 연속 ‘한국에서 가장 존경받는 기업’ 선정
# ...

# %%
temp = temp.drop(['Unnamed: 0'],axis=1)
temp.to_csv('아시아투데이.csv',encoding='utf-8-sig',index=None)
