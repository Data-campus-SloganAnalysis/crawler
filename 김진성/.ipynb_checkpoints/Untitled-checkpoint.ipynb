# %%
import pandas as pd
import os

csv_list = os.listdir('../csv모음')
csv_list
# Out:
# ['경향신문.csv',
#  '국민일보.csv',
#  '내일신문.csv',
#  '동아일보.csv',
#  '매일일보.csv',
#  '문화일보.csv',
#  '서울신문.csv',
#  '세계일보.csv',
#  '아시아투데이.csv',
#  '천지일보.csv',
#  '한겨례.csv',
#  '한국일보.csv']

# %%
temp = pd.read_csv('../csv모음/세계일보.csv',encoding='utf-8')
temp
# Out:
#     Unnamed: 0   언론사                                                 제목  \
# 0            0  세계일보           풀무원다논, 플립형 토핑 요거트 ‘요거톡’ 누적 판매량 1000만개 달성
# 1            1  세계일보              풀무원푸드머스, 롯데하이마트와 어린이집 전문 방역 서비스 제공 MO
# 2            2  세계일보                풀무원, 어린이 바른먹거리 교육에 ‘코로나19 예방 교육’ 실시
# 3            3  세계일보               풀무원식품 신임 대표에 김진홍 전 LG전자 글로벌마케팅센터장 선임
# 4            4  세계일보            풀무원, 60대 이상 고연령층 대상으로 '바른먹거리 교육' 진행했더니…
# 5            5  세계일보                   풀무원, 온라인 모니터 요원 ‘e-fresh’ 24기 모집
# 6            6  세계일보               풀무원다논, '내시피족' 위한 액티비아 요거트 활용 레시피 선보여
# 7            7  세계일보                                   풀무원식품 신임 대표에 김진홍
# 8            8  세계일보               풀무원 '바른먹거리 교육', 8년 만에 누적 어린이 10만명 돌파
# 9            9  세계일보                   풀무원, 국내 첫 ‘기능성 표시 일반식품’ 1호·2호 등록
# 10          10  세계일보                      풀무원, 올해 어린이 2만명 대상 '바른먹거리 교육'
# 11          11  세계일보         풀무원 올가홀푸드, 친환경 농업 발전 공로 '농림축산식품부 장관 표창' 수상
# ...

# %%
csv_dummy = pd.DataFrame(columns=['언론사','제목','내용'])

for i in csv_list:
    try:
        temp_df = pd.read_csv('../csv모음/'+i,encoding='utf-8',)
        print(temp_df.shape)
        print(i)
        csv_dummy.append(temp_df,ignore_index=True)
    except:
        temp_df = pd.read_csv('../csv모음/'+i,encoding='cp949')
        csv_dummy.append(temp_df,ignore_index=True)
# Out:
# (8, 3)
# 내일신문.csv
# (7, 3)
# 동아일보.csv
# (20, 3)
# 매일일보.csv
# (20, 3)
# 문화일보.csv
# (6, 3)
# 서울신문.csv
# (36, 3)
# 세계일보.csv
# (40, 3)
# 아시아투데이.csv
# (20, 3)
# 천지일보.csv
# (10, 3)
# 한겨례.csv
# (7, 3)
# 한국일보.csv

# %%
csv_dummy
# Out:
# Empty DataFrame
# Columns: [언론사, 제목, 내용]
# Index: []

# %%
temp = pd.read_csv('../csv모음/아시아투데이.csv',encoding='utf-8',)
temp
# Out:
#     Unnamed: 0     언론사                                                 제목  \
# 0            0  아시아투데이                 풀무원, ‘바른먹거리 캠페인’ 전국 확대…2만여명에 무상 교육
# 1            1  아시아투데이                  풀무원다논, 무주 공장 요거트 생산라인 증설…239억원 투입
# 2            2  아시아투데이              풀무원식품, 신임 대표에 김진홍 전 LG전자 글로벌마케팅센터장 선임
# 3            3  아시아투데이                풀무원, 어린이 2만2000명에 ‘바른먹거리 캠페인 교육’ 실시
# 4            4  아시아투데이                 풀무원, ‘대한민국소셜미디어대상’ 종합식품·소셜브랜드부문 대상
# 5            5  아시아투데이  풀무원, 어른들을 위한 ‘성인 바른먹거리 교육’ 실시…“어른이 먼저 불균형 식습관 ...
# 6            6  아시아투데이                              풀무원 ‘바른먹거리 교육’ 영역 넓힌다
# 7            7  아시아투데이                  풀무원녹즙, 3중 필터링 거친 노니주스 ‘노니엔클리어’ 출시
# 8            8  아시아투데이                       풀무원, ‘바른먹거리’ 교육 확대…올해 1만명 실시
# 9            9  아시아투데이       “용기째 요리”…풀무원, 용기형 가정간편식 ‘5분 키친 순두부 요리’ 3종 출시
# 10          10  아시아투데이                      풀무원, 간편식 ‘5분 키친 콩나물 요리’ 3종 선봬
# 11          11  아시아투데이                   풀무원, 11년 연속 ‘한국에서 가장 존경받는 기업’ 선정
# ...

# %%
temp = temp.drop(['Unnamed: 0'],axis=1)
temp.to_csv('아시아투데이.csv',encoding='utf-8-sig',index=None)

# %%
temp
# Out:
#        언론사                                                 제목  \
# 0   아시아투데이                 풀무원, ‘바른먹거리 캠페인’ 전국 확대…2만여명에 무상 교육
# 1   아시아투데이                  풀무원다논, 무주 공장 요거트 생산라인 증설…239억원 투입
# 2   아시아투데이              풀무원식품, 신임 대표에 김진홍 전 LG전자 글로벌마케팅센터장 선임
# 3   아시아투데이                풀무원, 어린이 2만2000명에 ‘바른먹거리 캠페인 교육’ 실시
# 4   아시아투데이                 풀무원, ‘대한민국소셜미디어대상’ 종합식품·소셜브랜드부문 대상
# 5   아시아투데이  풀무원, 어른들을 위한 ‘성인 바른먹거리 교육’ 실시…“어른이 먼저 불균형 식습관 ...
# 6   아시아투데이                              풀무원 ‘바른먹거리 교육’ 영역 넓힌다
# 7   아시아투데이                  풀무원녹즙, 3중 필터링 거친 노니주스 ‘노니엔클리어’ 출시
# 8   아시아투데이                       풀무원, ‘바른먹거리’ 교육 확대…올해 1만명 실시
# 9   아시아투데이       “용기째 요리”…풀무원, 용기형 가정간편식 ‘5분 키친 순두부 요리’ 3종 출시
# 10  아시아투데이                      풀무원, 간편식 ‘5분 키친 콩나물 요리’ 3종 선봬
# 11  아시아투데이                   풀무원, 11년 연속 ‘한국에서 가장 존경받는 기업’ 선정
# 12  아시아투데이                 풀무원 ‘뮤지엄김치간’, 개관 2주년 기념 관람료 50% 할인
# 13  아시아투데이                                    건강 식습관 풀무원이 키운다
# ...
