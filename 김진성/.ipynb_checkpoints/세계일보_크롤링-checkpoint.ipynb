# %%
import re
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd

# %%
import sys

sys.executable
# Out:
# 'C:\\ProgramData\\Anaconda3\\python.exe'

# %%
driver_path = './chromedriver.exe'

# %%
def clean_text(text):
    cleaned_text = re.sub('[a-zA-Z]', '', text)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]',
                          '', cleaned_text)
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# %%
def biz_khan(query,driver_path,page):
    domain = '세계일보'
    driver = webdriver.Chrome(executable_path=driver_path)
        
    current_page = 1
    last_page =(int(page)-1)*10+1
    
    head_list = []
    data_list = []
    
    while current_page < last_page:
        driver = webdriver.Chrome(executable_path=driver_path)
        url_domain = 'https://search.naver.com/search.naver?where=news&query='
        news_domain ='&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=1&office_type=1&office_section_code=1&news_office_checked=1022&nso=&is_sug_officeid=0'
        url = url_domain + query +'&%2Ca%3A&start='+str(current_page)+ news_domain
        driver.get(url)
        soup = BeautifulSoup(driver.page_source,'html.parser')

        # 기사 url을 list형태로 반환
        try:
            news_list = soup.select('#main_pack > section > div > div.group_news > ul')
            url_list = []
            news_list = news_list[0].find_all('li')
            for url in news_list:
                url_list.append(str(url.find_all('a')[0].get('data-url')))
        except:
            print('기사가 없습니다.')
            driver.close()
            return 0
        driver.close()


        for url in url_list:
            driver = webdriver.Chrome(executable_path=driver_path)  # for Windows
            try:
                driver.get(url)
                time.sleep(1)
            except:
                print('link error')
                continue
            # try문 안에서 각자 언론사에 맞게 수정
            try:
                soup = BeautifulSoup(driver.page_source,'html.parser')
                head_list.append(soup.select('#title_sns')[0].text)
                data = soup.find('article',class_='viewBox').text
                data_list.append(' '.join(data))
            except:
                print(url)
                print('None_type')
            driver.close()
        current_page+=10
        
    output = pd.DataFrame({'언론사' : [domain]*len(head_list),
                          '제목' :  head_list,
                          '내용' : data_list})
    return output

biz = biz_khan('풀무원 바른먹거리',driver_path,5)
biz
# Out:
# link error
# http://www.economysegye.com/articles/view.html?aid=20130326001515&cid=7111000000000&OutUrl=naver
# None_type
# link error
#      언론사                                                 제목  \
# 0   세계일보           풀무원다논, 플립형 토핑 요거트 ‘요거톡’ 누적 판매량 1000만개 달성
# 1   세계일보              풀무원푸드머스, 롯데하이마트와 어린이집 전문 방역 서비스 제공 MO
# 2   세계일보                풀무원, 어린이 바른먹거리 교육에 ‘코로나19 예방 교육’ 실시
# 3   세계일보               풀무원식품 신임 대표에 김진홍 전 LG전자 글로벌마케팅센터장 선임
# 4   세계일보            풀무원, 60대 이상 고연령층 대상으로 '바른먹거리 교육' 진행했더니…
# 5   세계일보                   풀무원, 온라인 모니터 요원 ‘e-fresh’ 24기 모집
# 6   세계일보               풀무원다논, '내시피족' 위한 액티비아 요거트 활용 레시피 선보여
# 5   \n 풀 무 원 식 품 ( 대 표   김 진 홍 ) 은   바 른 먹 거 리 를  ...
# 6   \n 요 거 트   전 문   기 업   풀 무 원 다 논 ( 대 표   정 희 련...
# 7   \n \n \n \n 풀 무 원 은   풀 무 원 식 품 의   신 임   대 표 ...
# 8   \n 국 내   기 업 에 서   처 음 으 로   2 0 1 0 년   어 린 이...
# 9   \n \n \n \n 풀 무 원 이   일 반 식 품 에   대 한   기 능 성 ...
# 10  \n 전 국   돌 며   초 등 학 생 · 학 부 모   대 상   8 8 0 회...
# 11  \n 풀 무 원 은   풀 무 원   계 열 의   L O H A S   F r e...
# 12  \n 풀 무 원 ( 대 표   이 효 율 ) 은   공 정 거 래 위 원 회 가  ...
# 13  \n 풀 무 원 이   어 린 이 들 을   대 상 으 로   한   ‘ 바 른 먹...
# 14  \n 풀 무 원   ‘ 바 른   먹 거 리   캠 프 ’   개 최 \n \n 풀...
# 15  \n 풀 무 원 이   비 재 무 적   성 과 를   평 가 하 는   2 0 2...
# 16  \n \n \n \n 풀 무 원 과   푸 드 머 스 가   고 령 사 회 를   ...
# 17  \n   \n \n \n \n   식 생 활   캠 페 인   교 육 을   전 문...
# 18  \n 우 리 나 라   대 부 분   농 촌   지 역 이   초 고 령 사 회 로...
# 19  \n 풀 무 원 ,   “ 회 사   C I   없 이   차 라 리   백 지 로...
# 20  \n \n \n \n \n \n \n \n 풀 무 원 다 논 이   최 근   업 ...
# 21  \n   \n \n \n \n 풀 무 원 이   대 표 적 인   C S V ( 공...
# 22  \n 풀 무 원   美   브 랜 드   ' 와 일 드 우 드 '   두 부   제...
# 23  \n 우 리 나 라   대 부 분   농 촌   지 역 이   초 고 령 사 회 로...
# 24  \n   \n \n \n \n 풀 무 원 이   교 육 과 학 기 술 부 와   함...
# 25  \n                           이 규 석   풀 무 원 건 강...
# 26  \n \n 풀 무 원 샘 물 은   4 월 3 0 일 부 터   5 월 9 일 까 ...
# 27  \n \n 안 전 한   먹 거 리 에   대 한   고 객 들 의   관 심 이 ...
# 28  \n \n \n \n \n 풀 무 원 건 강 생 활 ( 대 표   유 창 하 ) 은...
# 29  \n 남 승 우   前   C E O   가 족 승 계   않 고   /   ‘ 1...
# 30  \n   \n \n \n \n 최 근   새 롭 게   떠 오 른   소 비   형...
# 31  \n \n 풀 무 원 의   충 북   음 성   물 류 사 업 장 에 서   화 ...
# 32  \n                         풀 무 원 은   1 2 일   창...
# 33  \n \n \n 풀 무 원 이   1 6 일   풀 무 원 재 단 을   출 범 시...
# 34  \n 홈 플 러 스 와   풀 무 원 식 품 은   상 품   판 매 금 액   일...
# 35  \n 풀 무 원 ,   교 육 부 와   공 동   캠 페 인 \n \n \n 풀 ...
# 36  \n 풀 무 원 ,   기 아 체 험 행 사 로   송 년 회   대 신 \n \n...

# %%
biz.to_csv('세계일보_크롤링_데이터.csv',encoding='utf-8-sig',index=None)
