# %%
import re
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd

# %%
driver_path = './chromedriver.exe'

# %%
def clean_text(text):
    cleaned_text = re.sub('[a-zA-Z]', '', text)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]',
                          '', cleaned_text)
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# %%
def biz_khan(query,driver_path,page):
    domain = '아시아투데이'
    driver = webdriver.Chrome(executable_path=driver_path)
    
    current_page = 1 #추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
    last_page =(int(page)-1)*10+1#추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
    
    head_list = []
    data_list = []
    
    while current_page < last_page:#추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
        print(current_page)
        driver = webdriver.Chrome(executable_path=driver_path)
        url_domain = 'https://search.naver.com/search.naver?where=news&query='
        news_domain ='&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=1&office_type=1&office_section_code=1&news_office_checked=2268&nso=&is_sug_officeid=0'
        url = url_domain + query +'&%2Ca%3A&start='+str(current_page) + news_domain#추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
        print(url)
        driver.get(url)
        soup = BeautifulSoup(driver.page_source,'html.parser')

        # 기사 url을 list형태로 반환
        try:
            news_list = soup.select('#main_pack > section > div > div.group_news > ul')
            url_list = []
            news_list = news_list[0].find_all('li')
            for url in news_list:
                url_list.append(str(url.find_all('a')[0].get('data-url')))
        except:
            print('기사가 없습니다.')
            driver.close()
            return 0
        driver.close()


        for url in url_list:
            driver = webdriver.Chrome(executable_path=driver_path)  # for Windows
            try:
                driver.get(url)
                time.sleep(1)
            except:
                print('link error')
                continue
            # try문 안에서 각자 언론사에 맞게 수정
            try:
                soup = BeautifulSoup(driver.page_source,'html.parser')
                head_list.append(soup.select('#section_top > div > h3')[0].text)
                data = soup.find('div',class_='news_bm').text
                data_list.append(' '.join(data))
            except:
                print(url)
                print('None_type')
            driver.close()
        current_page+=10#추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
        
    output = pd.DataFrame({'언론사' : [domain]*len(head_list),
                          '제목' :  head_list,
                          '내용' : data_list})
    return output

biz = biz_khan('삼성전자 슬로건',driver_path,3)#추가된 부분@@@@@@@@@@@@@@@@@@@@@@@@@
biz
# Out:
# 1
# https://search.naver.com/search.naver?where=news&query=삼성전자 슬로건&%2Ca%3A&start=1&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=1&office_type=1&office_section_code=1&news_office_checked=2268&nso=&is_sug_officeid=0
# 11
# https://search.naver.com/search.naver?where=news&query=삼성전자 슬로건&%2Ca%3A&start=11&sm=tab_opt&sort=0&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=1&office_type=1&office_section_code=1&news_office_checked=2268&nso=&is_sug_officeid=0
#        언론사                                        제목  \
# 0   아시아투데이        삼성전자, 가전제품 통합 슬로건 적용…‘이제는 가전을 나답게’
# 1   아시아투데이             삼성전자, 맞춤형 가전 체험 ‘나답게 스튜디오’ 운영
# 2   아시아투데이          삼성전자 하만, 국내 최초 오디오 브랜드 ‘인피니티’ 출시
# 3   아시아투데이       제일기획이 만든 삼성 갤럭시S21 광고, 누적 9000만뷰 돌파
# 4   아시아투데이          LG전자, 최대 200만원 할인전…가전특수 올해도 이어간다
# 5   아시아투데이                        삼성 전략, ‘메이크 포 인디아’
# 6   아시아투데이  삼성전자, ‘비스포크 큐브’ 이달 말 출시…크라우드 펀딩 통해 먼저 선봬
# 7   아시아투데이                    삼성전자서비스, KSQI 연속 1위 석권
# 8   아시아투데이    삼성전자, 인도 스마트폰 시장 점유율 2위 등극…LG폰도 판매량 증가
# 9   아시아투데이       ‘펫가전’ 공들이는 삼성·LG …돈 아끼지 않는 ‘펫족’ 잡아라
# 10  아시아투데이      레이쥔 샤오미 CEO, 삼성전자로부터 ‘웨이퍼 조형물’ 선물 받아
# 11  아시아투데이                   ‘아이폰 전문가’ KT…갤럭시는 非전문가?
# 12  아시아투데이         삼성전자, 인플루언서 마케팅 시동…‘팀 갤럭시’ 캠페인 시작
# 13  아시아투데이              삼성전자 DS부문 ‘19년 희망공부방 멘토’ 발대식
# 14  아시아투데이          함께 걷는 ‘삼성과 수원시’... 세계일류기업과 상생 도모
# 15  아시아투데이       삼성전자, 용인 저소득 청소년 버팀목 ‘희망공부방’ 장학금 전달
# 16  아시아투데이                     삼성전자, 中 ‘QLED 카니발’ 참가
# 17  아시아투데이       계속되는 폭염…삼성전자 ‘무풍에어컨’ 국내 판매 100만대 돌파
# 18  아시아투데이         삼성전자, 청소년 진로 탐색 프로그램 ‘드림락(樂)서’ 개최
# 19  아시아투데이       삼성전자, 美 제니맥스로부터 ‘기어VR’ 지재권 침해 소송 당해
#
#                                                    내용
# 0   c l i p 2 0 2 0 0 6 1 7 0 9 5 3 0 2 0 삼 성 전 자 ...
# 1   삼 성 전 자 ,   맞 춤 형   가 전   체 험 공 간   ‘ 나 답 게   ...
# 2   사 진 2 - I n f i n i t y   C L U B Z   2 5 0 0 ...
# 3   갤 럭 시   S 2 1   론 칭   광 고   이 미 지 _ 2 0 제 일 기 ...
# 4   P r i n t 0 관 련 종 목 L G 전 자 ( 0 6 6 5 7 0 ) , ...
# 5   메 이 크   포   인 디 아 0 홍 현 칠   삼 성 전 자   인 도 법 인 ...
# 6   삼 성 전 자 ,   국 내   시 장 에   ‘ 비 스 포 크   큐 브 ’   ...
# 7   c l i p 2 0 2 0 0 7 2 0 0 9 2 2 1 5 0 삼 성 전 자 ...
# 8   삼 성   갤 럭 시   S 2 0   출 처   삼 전 0 삼 성   갤 럭 시 ...
# 9   반 려 동 물   관 련   가 전 제 품 0 반 려 동 물   관 련   가 전 ...
# 10  레 이 쥔   샤 오 미   C E O   삼 성 전 자 로 부 터   받 은   ...
# 11  K a k a o T a l k _ 2 0 1 6 1 1 0 2 _ 1 3 5 3 ...
# 12  c l i p 2 0 1 9 0 7 2 2 0 9 1 2 3 6 1   삼 성 전 ...
# 13  삼 성 전 자 D S   희 망 공 부 방   발 대 식 0 a T 센 터 에 서 ...
# 14  함 께   걷 는   삼 성 과   수 원 시   1 0 ‘ 2 0 1 8   수 ...
# 15  삼 성 전 자   희 망 공 부 방 0 1 6 일   삼 성 전 자 가   용 인 ...
# 16  Q L E D   카 니 발 ( 2 ) 0 2 일   중 국   상 하 이   타 ...
# 17  삼 성 전 자   국 내   에 어 컨   1 0 0 만 대   돌 파 ( 1 ) ...
# 18    삼 성 전 자 와   경 기 도   교 육 청 이   함 께   주 최 하 는 ...
# 19    미 국   비 디 오 게 임 개 발 사 인   제 니 맥 스 가   삼 성 전 ...
